# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import statistics
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
ROOT_PATH = "/content/drive/MyDrive/AraLlamaProject/"
PRETRAIND_MODEL = "/content/drive/MyDrive/AraLlamaProject/Models/"
TOKENIZERS = "/content/drive/MyDrive/AraLlamaProject/tokenizers/"
FINTUNED_MODEL = "/content/drive/MyDrive/AraLlamaProject/Fine-tuning-models/"
DATASETS_PATH = "/content/drive/MyDrive/AraLlamaProject/Datasets/"
tasks = ["Arabic-Natural-Language-Inference","Arabic-Hate-Speech","Arabic-News-Articles","Arabic-Sentiment-Analysis"]
vocab_sizes = [16000,28000,44000]
token_methods = ["BPE","WLV","WPC"]
ARGS = [(3,16),(5,32),(10,32),(10,32)]

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_statistics_with_pointgraph_nofarasa(f1_list,task,farasa):

  x = np.array(['16k', '28k',"44k"])
  y_bpe = f1_list[0]
  y_wordpiece = f1_list[1]
  y_word_level = f1_list[2]
  y_bpe_with_farasa = f1_list[3]
  plt.figure(figsize=(10, 6))
  plt.plot(x, y_bpe,  "--o",label="BPE")
  plt.plot(x, y_wordpiece, "--o",label="WordPiece")
  plt.plot(x, y_word_level,  "--o",label="Word-level")
  plt.plot(x, y_bpe_with_farasa,  "--o",label="bpe-with-farasa")
  plt.xlabel("vocabulary sizes")
  plt.ylabel("Weighted F1 score")
  plt.title(f"{task}")
  plt.legend()
  plt.ylim([0.5, 0.85])
  plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_statistics_with_pointgraph_nofarasa(f1_list,task,farasa):

  x = np.array(['16k', '28k',"44k"])
  y_bpe = f1_list[0]
  y_wordpiece = f1_list[1]
  y_word_level = f1_list[2]
  y_bpe_with_farasa = f1_list[3]
  plt.figure(figsize=(10, 6))
  plt.plot(x, y_bpe,  "--o",label="BPE")
  plt.plot(x, y_wordpiece, "--o",label="WordPiece")
  plt.plot(x, y_word_level,  "--o",label="Word-level")
  plt.plot(x, y_bpe_with_farasa,  "--o",label="bpe-with-farasa")
  plt.xlabel("vocabulary sizes")
  plt.ylabel("Accuracy score")
  plt.title(f"{task}")
  plt.legend()
  plt.ylim([0.97, 0.99])
  plt.show()

# %%
# prompt: change the last code to have different markers for each data point and have bigger legends and bigger font

def plot_statistics_with_pointgraph_nofarasa(f1_list,task,farasa):

  x = np.array(['16k', '28k',"44k"])
  y_bpe = f1_list[0]
  y_wordpiece = f1_list[1]
  y_word_level = f1_list[2]
  y_bpe_with_farasa = f1_list[3]
  sns.set_theme(style="ticks",font_scale=1.2)
  plt.figure(figsize=(10, 6))
  sns.lineplot(x=x, y=y_bpe,  label="BPE" ,markers="o",markersize=10)
  sns.lineplot(x=x, y=y_wordpiece, label="WordPiece",markers="s",markersize=10)
  sns.lineplot(x=x, y=y_word_level,  label="Word-level",markers="v",markersize=10)
  sns.lineplot(x=x, y=y_bpe_with_farasa,  label="bpe-with-farasa",markers="D",markersize=10)
  plt.xlabel("vocabulary sizes")
  plt.ylabel("Accuracy score")
  plt.title(f"{task}")
  plt.legend(prop={'size': 16})
  plt.ylim([0.97, 0.99])
  plt.show()

# %%
# !pip install SciencePlots

# %%
# !sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended cm-super
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cm-super-minimal dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern
#   fonts-noto-mono fonts-texgyre fonts-urw-base35 ghostscript
#   libapache-pom-java libcommons-logging-java libcommons-parent-java
#   libfontbox-java libfontenc1 libgs9 libgs9-common libidn12 libijs-0.35
#   libjbig2dec0 libkpathsea6 libpdfbox-java libptexenc1 libruby3.0 libsynctex2
#   libteckit0 libtexlua53 libtexluajit2 libwoff1 libzzip-0-13 lmodern
#   pfb2t1c2pfb poppler-data preview-latex-style rake ruby ruby-net-telnet
#   ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0 rubygems-integration t1utils
#   tex-common tex-gyre texlive-base texlive-binaries texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
#   xfonts-encodings xfonts-utils
# Suggested packages:
# ...

# %%
# prompt: change the last code to have different markers for each data point and have bigger legends and bigger font
import matplotlib.pyplot as plt
import scienceplots
def plot_statistics_with_pointgraph_nofarasa(f1_list,task,farasa):

  x = np.array(['16k', '28k',"44k"])
  y_bpe = f1_list[0]
  y_wordpiece = f1_list[1]
  y_word_level = f1_list[2]
  y_bpe_with_farasa = f1_list[3]
  plt.figure(figsize=(6, 6))
  plt.style.use(['science','ieee'])
  with plt.style.context(['science','ieee']):
    # plt.figure()
    plt.plot(x, y_bpe,  "--o",label="BPE")
    plt.plot(x, y_wordpiece, "-^",label="WordPiece")
    plt.plot(x, y_word_level,  ":*",label="Word-level")
    plt.plot(x, y_bpe_with_farasa,  "-.s",label="Morphological")
    plt.xlabel("Vocabulary sizes")
    plt.ylabel("Weighted F1 score")
    plt.title(f"{task}")
    plt.legend(prop={'size': 5})
    # plt.ylim([0.50, 1.0])
    plt.show()
# ,markersize=10
# prop={'size': 15}
# figsize=(10, 6)

# %%
import pandas
farasa = "nofarasa"
vocab_sizes = [16000,28000,44000]
token_methods = ["BPE","WLV","WPC","BPE-farasa"]
is_farasa = ["nofarasa"]
for task in tasks:
  print(f"task {task}")
  f1_list = []
  token_list = []
  for tok in token_methods:
    token_list = []
    for vocab in vocab_sizes:
      farasa = "nofarasa"
      if(tok == "BPE-farasa"):
        tok1 = "BPE"
        farasa = "with-farasa"
        df = pandas.read_excel(FINTUNED_MODEL+"{}/xlm-roberta-{}-{}/{}_paramaters.xlsx".format(task,farasa,vocab , tok1))
        value = df['eval_accuracy'].values[-1:]
        token_list.append(value[0])
        continue
      df = pandas.read_excel(FINTUNED_MODEL+"{}/xlm-roberta-{}-{}/{}_paramaters.xlsx".format(task,farasa,vocab , tok))
      value = df['eval_accuracy'].values[-1:]
      token_list.append(value[0])
    f1_list.append(token_list)
  print(f1_list)
  plot_statistics_with_pointgraph_nofarasa(f1_list,task,farasa)
# Out:
# task Arabic-Natural-Language-Inference
# [[0.5252, 0.532, 0.5336], [0.5428, 0.5428, 0.5424], [0.5196, 0.5352, 0.5296], [0.5692, 0.5732, 0.5644]]
# task Arabic-Hate-Speech
# [[0.7333333333333333, 0.7145299145299145, 0.705982905982906], [0.7008547008547008, 0.7128205128205128, 0.7128205128205128], [0.6974358974358974, 0.7128205128205128, 0.6974358974358974], [0.717948717948718, 0.7230769230769231, 0.7230769230769231]]
# task Arabic-News-Articles
# [[0.9749450549450549, 0.9764835164835165, 0.9740659340659341], [0.9738461538461538, 0.9723076923076923, 0.9742857142857143], [0.9727472527472527, 0.9745054945054945, 0.9738461538461538], [0.9749450549450549, 0.9769230769230769, 0.978021978021978]]
# task Arabic-Sentiment-Analysis
# [[0.8310012226599647, 0.8205406874066024, 0.8273332427659286], [0.755332155957071, 0.7557397092786307, 0.766200244531993], [0.7884798261105828, 0.7754381198206766, 0.7808721641081375], [0.7937780192908572, 0.7899741882896346, 0.7905175927183806]]
